# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
#URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="


counter =1
call = 1

# set up lists to hold reponse info
city_list = []
lat_list = []
lng_list = []
max_temp = []
humidity = []
cloudiness_list = []
wind_speed = []
country_list = []
date_list = []

# Set a counter
counter = 0
call = 1

print("Beginning Data Retrieval")
print("------------------------------")

for city in cities:
    
        try:
            response = requests.get(query_url + city).json()
            city_list.append(response['name'])
            lat_list.append(response['coord']['lat'])
            lng_list.append(response['coord']['lon'])
            max_temp.append(response['main']['temp'])
            humidity.append(response['main']['humidity'])
            cloudiness_list.append(response['clouds']['all'])
            wind_speed.append(response['wind']['speed'])
            country_list.append(response["sys"]["country"])
            date_list.append(response["dt"])
            
            if counter >49:
                #print(f'Processing Record {counter} of Set {call} | {city}')
                counter = 0
                call = call + 1
                time.sleep(1.1)
            else:
                counter += 1
                print(f'Processing Record {counter} of Set {call} | {city}')
            
        except:
            print("City not found. Skipping...")

print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | codrington
# Processing Record 2 of Set 1 | yulara
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | burayevo
# Processing Record 5 of Set 1 | ahipara
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | marawi
# Processing Record 8 of Set 1 | mandalgovi
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 11 of Set 1 | tshikapa
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | mocuba
# Processing Record 14 of Set 1 | kurbnesh
# Processing Record 15 of Set 1 | biu
# City not found. Skipping...
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | japura
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | paamiut
# Processing Record 22 of Set 1 | ixtapa
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | kaitangata
# City not found. Skipping...
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | padang
# Processing Record 28 of Set 1 | casimiro de abreu
# Processing Record 29 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | inyonga
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | mandali
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | chara
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | upington
# Processing Record 44 of Set 1 | kailua
# Processing Record 45 of Set 1 | saint-pierre
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | faya
# Processing Record 49 of Set 1 | guayaramerin
# Processing Record 50 of Set 1 | neftcala
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | lleida
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | takayama
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | bud
# Processing Record 8 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 9 of Set 2 | dalby
# Processing Record 10 of Set 2 | olafsvik
# Processing Record 11 of Set 2 | burnie
# Processing Record 12 of Set 2 | tautira
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | aberystwyth
# Processing Record 15 of Set 2 | richards bay
# Processing Record 16 of Set 2 | aranda de duero
# Processing Record 17 of Set 2 | qaqortoq
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | pimentel
# Processing Record 21 of Set 2 | penzance
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | eyl
# City not found. Skipping...
# Processing Record 25 of Set 2 | ribeira grande
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | pandan
# Processing Record 28 of Set 2 | rocha
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | unai
# Processing Record 32 of Set 2 | kolda
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | oranjemund
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | paita
# Processing Record 37 of Set 2 | vostok
# Processing Record 38 of Set 2 | terme
# City not found. Skipping...
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | pacific grove
# Processing Record 41 of Set 2 | banff
# Processing Record 42 of Set 2 | dali
# Processing Record 43 of Set 2 | hanmer springs
# Processing Record 44 of Set 2 | maku
# Processing Record 45 of Set 2 | senec
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 2 | nhulunbuy
# Processing Record 47 of Set 2 | mahanoro
# Processing Record 48 of Set 2 | champerico
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | merauke
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | cherskiy
# Processing Record 3 of Set 3 | linxia
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | papara
# Processing Record 6 of Set 3 | coruripe
# Processing Record 7 of Set 3 | duku
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | naze
# Processing Record 11 of Set 3 | sao filipe
# Processing Record 12 of Set 3 | margate
# City not found. Skipping...
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | nelson bay
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | eureka
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | khotynets
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | diffa
# Processing Record 21 of Set 3 | labuhan
# Processing Record 22 of Set 3 | nuuk
# Processing Record 23 of Set 3 | orlik
# Processing Record 24 of Set 3 | cerrito
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | barretos
# Processing Record 28 of Set 3 | bouloupari
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | nantong
# Processing Record 31 of Set 3 | port lincoln
# Processing Record 32 of Set 3 | de-kastri
# Processing Record 33 of Set 3 | suntar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | kiruna
# Processing Record 37 of Set 3 | lola
# Processing Record 38 of Set 3 | arzgir
# Processing Record 39 of Set 3 | manicore
# Processing Record 40 of Set 3 | port macquarie
# Processing Record 41 of Set 3 | kokoda
# Processing Record 42 of Set 3 | huarmey
# Processing Record 43 of Set 3 | cocorit
# City not found. Skipping...
# Processing Record 44 of Set 3 | ariquemes
# Processing Record 45 of Set 3 | nova russas
# Processing Record 46 of Set 3 | camapua
# Processing Record 47 of Set 3 | nishihara
# Processing Record 48 of Set 3 | natal
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 50 of Set 3 | bukachacha
# Processing Record 1 of Set 4 | louth
# Processing Record 2 of Set 4 | kimbe
# Processing Record 3 of Set 4 | sisimiut
# Processing Record 4 of Set 4 | skerries
# Processing Record 5 of Set 4 | oistins
# City not found. Skipping...
# Processing Record 6 of Set 4 | mangrol
# Processing Record 7 of Set 4 | katangli
# Processing Record 8 of Set 4 | chaohu
# City not found. Skipping...
# Processing Record 9 of Set 4 | fortuna
# Processing Record 10 of Set 4 | goderich
# Processing Record 11 of Set 4 | buraydah
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | jacareacanga
# Processing Record 14 of Set 4 | cape town
# Processing Record 15 of Set 4 | birobidzhan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | noshiro
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | college
# Processing Record 20 of Set 4 | tarko-sale
# Processing Record 21 of Set 4 | erenhot
# Processing Record 22 of Set 4 | half moon bay
# Processing Record 23 of Set 4 | westport
# Processing Record 24 of Set 4 | korla
# Processing Record 25 of Set 4 | jaque
# Processing Record 26 of Set 4 | fayaoue
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | vieste
# Processing Record 29 of Set 4 | aripuana
# Processing Record 30 of Set 4 | guerrero negro
# Processing Record 31 of Set 4 | abu samrah
# Processing Record 32 of Set 4 | polyarnyy
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | dunedin
# Processing Record 35 of Set 4 | chinsali
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | tahe
# Processing Record 38 of Set 4 | alofi
# Processing Record 39 of Set 4 | radhan
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | san luis
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | batote
# Processing Record 44 of Set 4 | fasa
# Processing Record 45 of Set 4 | biskamzha
# Processing Record 46 of Set 4 | zlocieniec
# Processing Record 47 of Set 4 | warangal
# Processing Record 48 of Set 4 | esperance
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | tigil
# Processing Record 1 of Set 5 | marataizes
# Processing Record 2 of Set 5 | srednekolymsk
# Processing Record 3 of Set 5 | cockburn town
# Processing Record 4 of Set 5 | okha
# City not found. Skipping...
# Processing Record 5 of Set 5 | ingham
# Processing Record 6 of Set 5 | lethem
# Processing Record 7 of Set 5 | saskylakh
# Processing Record 8 of Set 5 | egvekinot
# Processing Record 9 of Set 5 | devils lake
# Processing Record 10 of Set 5 | khasan
# Processing Record 11 of Set 5 | jalu
# Processing Record 12 of Set 5 | vestmannaeyjar
# Processing Record 13 of Set 5 | boone
# Processing Record 14 of Set 5 | ilulissat
# Processing Record 15 of Set 5 | boyolangu
# Processing Record 16 of Set 5 | touros
# Processing Record 17 of Set 5 | northam
# Processing Record 18 of Set 5 | piacabucu
# City not found. Skipping...
# Processing Record 19 of Set 5 | saint pete beach
# Processing Record 20 of Set 5 | parkes
# Processing Record 21 of Set 5 | vallenar
# Processing Record 22 of Set 5 | turka
# Processing Record 23 of Set 5 | tarauaca
# Processing Record 24 of Set 5 | olden
# Processing Record 25 of Set 5 | corinth
# City not found. Skipping...
# Processing Record 26 of Set 5 | moerai
# Processing Record 27 of Set 5 | thinadhoo
# Processing Record 28 of Set 5 | belmonte
# Processing Record 29 of Set 5 | lebu
# Processing Record 30 of Set 5 | juegang
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | tucurui
# Processing Record 33 of Set 5 | vila franca do campo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 5 | tashla
# Processing Record 35 of Set 5 | matara
# Processing Record 36 of Set 5 | ignatovka
# Processing Record 37 of Set 5 | airai
# Processing Record 38 of Set 5 | yonibana
# Processing Record 39 of Set 5 | tiksi
# Processing Record 40 of Set 5 | starachowice
# Processing Record 41 of Set 5 | isangel
# Processing Record 42 of Set 5 | fukue
# Processing Record 43 of Set 5 | ponta do sol
# City not found. Skipping...
# Processing Record 44 of Set 5 | urumqi
# Processing Record 45 of Set 5 | maningrida
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | byron bay
# Processing Record 49 of Set 5 | yarim
# Processing Record 50 of Set 5 | hasaki
# Processing Record 1 of Set 6 | meadow lake
# Processing Record 2 of Set 6 | murmashi
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | muroto
# Processing Record 5 of Set 6 | mangan
# Processing Record 6 of Set 6 | jijiang
# Processing Record 7 of Set 6 | port shepstone
# Processing Record 8 of Set 6 | okhotsk
# Processing Record 9 of Set 6 | marsh harbour
# Processing Record 10 of Set 6 | verkhnevilyuysk
# Processing Record 11 of Set 6 | spring valley
# Processing Record 12 of Set 6 | belfast
# Processing Record 13 of Set 6 | chapais
# Processing Record 14 of Set 6 | fort nelson
# Processing Record 15 of Set 6 | sapa
# Processing Record 16 of Set 6 | lashio
# Processing Record 17 of Set 6 | talnakh
# Processing Record 18 of Set 6 | zhuhai
# Processing Record 19 of Set 6 | pisco
# Processing Record 20 of Set 6 | ust-omchug
# Processing Record 21 of Set 6 | leh
# City not found. Skipping...
# Processing Record 22 of Set 6 | umm lajj
# Processing Record 23 of Set 6 | visby
# Processing Record 24 of Set 6 | gombe
# Processing Record 25 of Set 6 | mayo
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | acapulco
# Processing Record 28 of Set 6 | piney green
# Processing Record 29 of Set 6 | port hardy
# Processing Record 30 of Set 6 | gurupa
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | isaka
# Processing Record 33 of Set 6 | katsuura
# Processing Record 34 of Set 6 | berlevag
# Processing Record 35 of Set 6 | cobija
# Processing Record 36 of Set 6 | ancud
# Processing Record 37 of Set 6 | nova olimpia
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | quatre cocos
# Processing Record 40 of Set 6 | namibe
# Processing Record 41 of Set 6 | mount gambier
# Processing Record 42 of Set 6 | mombaca
# Processing Record 43 of Set 6 | beatrice
# Processing Record 44 of Set 6 | masyaf
# Processing Record 45 of Set 6 | mahon
# Processing Record 46 of Set 6 | waingapu
# Processing Record 47 of Set 6 | barcelos
# Processing Record 48 of Set 6 | sakakah
# Processing Record 49 of Set 6 | veraval
# Processing Record 50 of Set 6 | praia da vitoria
# City not found. Skipping...
# Processing Record 1 of Set 7 | sistranda
# City not found. Skipping...
# Processing Record 2 of Set 7 | port blair
# Processing Record 3 of Set 7 | rongcheng
# Processing Record 4 of Set 7 | yerofey pavlovich
# Processing Record 5 of Set 7 | bichura
# Processing Record 6 of Set 7 | adrar
# Processing Record 7 of Set 7 | roma
# Processing Record 8 of Set 7 | shakiso
# Processing Record 9 of Set 7 | totma
# Processing Record 10 of Set 7 | yumaguzino
# Processing Record 11 of Set 7 | arawa
# Processing Record 12 of Set 7 | marzuq
# Processing Record 13 of Set 7 | atar
# Processing Record 14 of Set 7 | klyuchi
# Processing Record 15 of Set 7 | alibag
# Processing Record 16 of Set 7 | beringovskiy
# Processing Record 17 of Set 7 | luanda
# City not found. Skipping...
# Processing Record 18 of Set 7 | taoudenni
# Processing Record 19 of Set 7 | sao francisco
# Processing Record 20 of Set 7 | luderitz
# Processing Record 21 of Set 7 | husavik
# Processing Record 22 of Set 7 | anton lizardo
# Processing Record 23 of Set 7 | podbrdo
# Processing Record 24 of Set 7 | dawson creek
# Processing Record 25 of Set 7 | tapejara
# Processing Record 26 of Set 7 | porto empedocle
# Processing Record 27 of Set 7 | saint anthony
# Processing Record 28 of Set 7 | salalah
# Processing Record 29 of Set 7 | maturin
# Processing Record 30 of Set 7 | vrangel
# Processing Record 31 of Set 7 | smithers
# Processing Record 32 of Set 7 | ugoofaaru
# Processing Record 33 of Set 7 | bar harbor
# Processing Record 34 of Set 7 | muros
# City not found. Skipping...
# Processing Record 35 of Set 7 | nome
# Processing Record 36 of Set 7 | coihaique
# Processing Record 37 of Set 7 | agadir
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | kutum
# Processing Record 40 of Set 7 | abu zabad
# Processing Record 41 of Set 7 | boa vista
# Processing Record 42 of Set 7 | rio gallegos
# Processing Record 43 of Set 7 | bafata
# Processing Record 44 of Set 7 | aasiaat
# Processing Record 45 of Set 7 | kavaratti
# Processing Record 46 of Set 7 | mahibadhoo
# Processing Record 47 of Set 7 | caetite
# Processing Record 48 of Set 7 | komsomolskiy
# Processing Record 49 of Set 7 | surman
# Processing Record 50 of Set 7 | sawtell
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | najran
# Processing Record 3 of Set 8 | mayahi
# Processing Record 4 of Set 8 | strezhevoy
# City not found. Skipping...
# Processing Record 5 of Set 8 | progreso
# Processing Record 6 of Set 8 | saint-leu
# Processing Record 7 of Set 8 | pontes e lacerda
# City not found. Skipping...
# Processing Record 8 of Set 8 | franca
# Processing Record 9 of Set 8 | hobyo
# Processing Record 10 of Set 8 | bata
# Processing Record 11 of Set 8 | ermoupolis
# Processing Record 12 of Set 8 | gotsu
# Processing Record 13 of Set 8 | basco
# Processing Record 14 of Set 8 | prince rupert
# Processing Record 15 of Set 8 | port moresby
# Processing Record 16 of Set 8 | port hedland
# Processing Record 17 of Set 8 | torbay
# Processing Record 18 of Set 8 | gamba
# Processing Record 19 of Set 8 | brae
# Processing Record 20 of Set 8 | birao
# Processing Record 21 of Set 8 | carnarvon
# Processing Record 22 of Set 8 | sana
# City not found. Skipping...
# Processing Record 23 of Set 8 | elko
# Processing Record 24 of Set 8 | myaundzha
# Processing Record 25 of Set 8 | abilene
# Processing Record 26 of Set 8 | noumea
# Processing Record 27 of Set 8 | clyde river
# Processing Record 28 of Set 8 | ler
# Processing Record 29 of Set 8 | san ramon de la nueva oran
# Processing Record 30 of Set 8 | conde
# Processing Record 31 of Set 8 | laguna
# City not found. Skipping...
# Processing Record 32 of Set 8 | ketchikan
# Processing Record 33 of Set 8 | vozdvizhenka
# Processing Record 34 of Set 8 | tiznit
# Processing Record 35 of Set 8 | rundu
# Processing Record 36 of Set 8 | mogadouro
# Processing Record 37 of Set 8 | lasa
# Processing Record 38 of Set 8 | avdon
# Processing Record 39 of Set 8 | chicama
# Processing Record 40 of Set 8 | matamoros
# Processing Record 41 of Set 8 | tres arroyos
# Processing Record 42 of Set 8 | fare
# Processing Record 43 of Set 8 | bahia honda
# Processing Record 44 of Set 8 | bamnet narong
# Processing Record 45 of Set 8 | berdigestyakh
# City not found. Skipping...
# Processing Record 46 of Set 8 | tangkak
# Processing Record 47 of Set 8 | chestermere
# City not found. Skipping...
# Processing Record 48 of Set 8 | auka
# Processing Record 49 of Set 8 | ferme-neuve
# Processing Record 50 of Set 8 | coquimbo
# Processing Record 1 of Set 9 | nemuro
# Processing Record 2 of Set 9 | hualmay
# Processing Record 3 of Set 9 | baykit
# City not found. Skipping...
# Processing Record 4 of Set 9 | kaka
# Processing Record 5 of Set 9 | wanaka
# Processing Record 6 of Set 9 | tessalit
# Processing Record 7 of Set 9 | svetlyy
# Processing Record 8 of Set 9 | huanren
# Processing Record 9 of Set 9 | arrifes
# City not found. Skipping...
# Processing Record 10 of Set 9 | kachiry
# Processing Record 11 of Set 9 | kikwit
# Processing Record 12 of Set 9 | alamos
# Processing Record 13 of Set 9 | douentza
# Processing Record 14 of Set 9 | coos bay
# Processing Record 15 of Set 9 | gladstone
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | obihiro
# Processing Record 18 of Set 9 | atherton
# Processing Record 19 of Set 9 | jinchang
# City not found. Skipping...
# Processing Record 20 of Set 9 | kincardine
# Processing Record 21 of Set 9 | rancho palos verdes
# Processing Record 22 of Set 9 | kamiiso
# Processing Record 23 of Set 9 | tura
# Processing Record 24 of Set 9 | nouakchott
# Processing Record 25 of Set 9 | luau
# Processing Record 26 of Set 9 | kyrylivka
# Processing Record 27 of Set 9 | lata
# Processing Record 28 of Set 9 | christchurch
# Processing Record 29 of Set 9 | asosa
# City not found. Skipping...
# Processing Record 30 of Set 9 | bilibino
# Processing Record 31 of Set 9 | tortoli
# City not found. Skipping...
# Processing Record 32 of Set 9 | abashiri
# Processing Record 33 of Set 9 | palmer
# City not found. Skipping...
# Processing Record 34 of Set 9 | qui nhon
# Processing Record 35 of Set 9 | ashington
# Processing Record 36 of Set 9 | hailey
# Processing Record 37 of Set 9 | garachine
# Processing Record 38 of Set 9 | mangai
# Processing Record 39 of Set 9 | tangshan
# Processing Record 40 of Set 9 | yaan
# Processing Record 41 of Set 9 | wanning
# Processing Record 42 of Set 9 | angoche
# Processing Record 43 of Set 9 | flinders
# City not found. Skipping...
# Processing Record 44 of Set 9 | lakhdenpokhya
# Processing Record 45 of Set 9 | leningradskiy
# Processing Record 46 of Set 9 | geraldton
# Processing Record 47 of Set 9 | tongren
# Processing Record 48 of Set 9 | sisophon
# Processing Record 49 of Set 9 | muriti
# City not found. Skipping...
# Processing Record 50 of Set 9 | cianorte
# Processing Record 1 of Set 10 | huilong
# Processing Record 2 of Set 10 | salinopolis
# Processing Record 3 of Set 10 | jovellar
# Processing Record 4 of Set 10 | batagay-alyta
# Processing Record 5 of Set 10 | saint-augustin
# Processing Record 6 of Set 10 | talavera
# Processing Record 7 of Set 10 | sorsk
# Processing Record 8 of Set 10 | palimbang
# Processing Record 9 of Set 10 | kamenka
# Processing Record 10 of Set 10 | grand gaube
# Processing Record 11 of Set 10 | waddan
# City not found. Skipping...
# Processing Record 12 of Set 10 | norman wells
# Processing Record 13 of Set 10 | china
# Processing Record 14 of Set 10 | slave lake
# Processing Record 15 of Set 10 | marion
# Processing Record 16 of Set 10 | forchheim
# Processing Record 17 of Set 10 | baj baj
# Processing Record 18 of Set 10 | sungaipenuh
# Processing Record 19 of Set 10 | zhoukou
# Processing Record 20 of Set 10 | ginda
# Processing Record 21 of Set 10 | ende
# Processing Record 22 of Set 10 | russell
# Processing Record 23 of Set 10 | pundaguitan
# Processing Record 24 of Set 10 | aykhal
# Processing Record 25 of Set 10 | abu dhabi
# Processing Record 26 of Set 10 | vytegra
# Processing Record 27 of Set 10 | payo
# Processing Record 28 of Set 10 | mawlaik
# Processing Record 29 of Set 10 | isla vista
# Processing Record 30 of Set 10 | bjornevatn
# Processing Record 31 of Set 10 | port keats
# Processing Record 32 of Set 10 | nizhniy kuranakh
# City not found. Skipping...
# Processing Record 33 of Set 10 | isabela
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 10 | kirkenaer
# Processing Record 35 of Set 10 | frontera
# Processing Record 36 of Set 10 | vuktyl
# Processing Record 37 of Set 10 | somerset
# Processing Record 38 of Set 10 | chernyshevskiy
# Processing Record 39 of Set 10 | hays
# Processing Record 40 of Set 10 | hambantota
# Processing Record 41 of Set 10 | cabedelo
# Processing Record 42 of Set 10 | kaffrine
# Processing Record 43 of Set 10 | krasnyy chikoy
# Processing Record 44 of Set 10 | boca do acre
# Processing Record 45 of Set 10 | channel-port aux basques
# Processing Record 46 of Set 10 | ajaccio
# Processing Record 47 of Set 10 | kahului
# Processing Record 48 of Set 10 | vavoua
# Processing Record 49 of Set 10 | kununurra
# Processing Record 50 of Set 10 | la paz
# Processing Record 1 of Set 11 | prainha
# Processing Record 2 of Set 11 | north bend
# Processing Record 3 of Set 11 | jilib
# Processing Record 4 of Set 11 | maltahohe
# Processing Record 5 of Set 11 | lunsar
# Processing Record 6 of Set 11 | golkoy
# Processing Record 7 of Set 11 | tanout
# Processing Record 8 of Set 11 | kawalu
# City not found. Skipping...
# Processing Record 9 of Set 11 | goure
# Processing Record 10 of Set 11 | yantarnyy
# Processing Record 11 of Set 11 | mariinsk
# Processing Record 12 of Set 11 | unity
# Processing Record 13 of Set 11 | kaeo
# Processing Record 14 of Set 11 | vanimo
# Processing Record 15 of Set 11 | rizhao
# Processing Record 16 of Set 11 | akim swedru
# Processing Record 17 of Set 11 | saravan
# Processing Record 18 of Set 11 | hoceni
# Processing Record 19 of Set 11 | darab
# Processing Record 20 of Set 11 | san cristobal
# Processing Record 21 of Set 11 | omboue
# Processing Record 22 of Set 11 | nokaneng
# Processing Record 23 of Set 11 | noboribetsu
# Processing Record 24 of Set 11 | karratha
# Processing Record 25 of Set 11 | batemans bay
# Processing Record 26 of Set 11 | kieta
# Processing Record 27 of Set 11 | chumikan
# Processing Record 28 of Set 11 | buta
# Processing Record 29 of Set 11 | muana
# Processing Record 30 of Set 11 | southbridge
# Processing Record 31 of Set 11 | sacramento
# Processing Record 32 of Set 11 | san antonio
# Processing Record 33 of Set 11 | kingaroy
# Processing Record 34 of Set 11 | lakewood
# Processing Record 35 of Set 11 | flic en flac
# City not found. Skipping...
# Processing Record 36 of Set 11 | poopo
# Processing Record 37 of Set 11 | afua
# City not found. Skipping...
# Processing Record 38 of Set 11 | homer
# Processing Record 39 of Set 11 | channahon
# Processing Record 40 of Set 11 | nara
# Processing Record 41 of Set 11 | port-gentil
# Processing Record 42 of Set 11 | jilavele
# Processing Record 43 of Set 11 | erdenet
# Processing Record 44 of Set 11 | bonavista
# Processing Record 45 of Set 11 | lagunas
# Processing Record 46 of Set 11 | oktyabrskiy
# Processing Record 47 of Set 11 | cabinda
# Processing Record 48 of Set 11 | turbat
# Processing Record 49 of Set 11 | kruisfontein
# Processing Record 50 of Set 11 | saint-joseph
# Processing Record 1 of Set 12 | kupino
# Processing Record 2 of Set 12 | aanekoski
# Processing Record 3 of Set 12 | cap malheureux
# Processing Record 4 of Set 12 | huambo
# Processing Record 5 of Set 12 | mushie
# Processing Record 6 of Set 12 | ilesha
# Processing Record 7 of Set 12 | tigre
# Processing Record 8 of Set 12 | viedma
# Processing Record 9 of Set 12 | staryy nadym
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | lavrentiya
# Processing Record 12 of Set 12 | urubicha
# Processing Record 13 of Set 12 | bridgetown
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a data frame
cities_df = pd.DataFrame({"City":city_list,
                          "Lat": lat_list,
                          "Lng":lng_list,
                          "Max Temp":max_temp,
                          "Humidity":humidity,
                          "Cloudiness":cloudiness_list,
                          "Wind Speed":wind_speed,
                          "Country":country_list,
                          "Date":date_list})

#Export the city data into a .csv
cities_df.to_csv("cities_data.csv", index = False)

#Display the DataFrame
cities_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Codrington -38.2667  141.9667     43.41        95           5
# 1          Yulara -25.2406  130.9889     56.19        42          64
# 2         Mataura -46.1927  168.8643     43.79        92          99
# 3        Burayevo  55.8407   55.4083     35.17        90          82
# 4         Ahipara -35.1667  173.1667     59.07        77         100
# ..            ...      ...       ...       ...       ...         ...
# 569  Staryy Nadym  65.6118   72.6842     46.92        75          99
# 570         Kumul  42.8000   93.4500     79.84        17          94
# 571    Lavrentiya  65.5833 -171.0000     38.23        74         100
# 572      Urubichá -15.3833  -62.9500     83.75        46          89
# 573    Bridgetown  13.1000  -59.6167     86.49        66          20
#
#      Wind Speed Country        Date
# 0          7.72      AU  1653241331
# 1          7.85      AU  1653241368
# 2          7.20      NZ  1653241368
# 3          4.25      RU  1653241369
# 4         10.58      NZ  1653241369
# ..          ...     ...         ...
# 569       23.60      RU  1653241597
# 570        8.75      CN  1653241597
# 571        7.65      RU  1653241597
# 572        3.89      BO  1653241598
# 573       20.71      BB  1653241598
#
# [574 rows x 9 columns]

# %%
cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean    19.427498   19.127124   65.470767   68.203833   57.888502    7.930052
# std     32.951759   92.123511   17.025778   23.672251   38.216223    5.337475
# min    -54.800000 -179.166700   19.630000    6.000000    0.000000    0.000000
# 25%     -8.138275  -59.471350   53.945000   54.000000   20.000000    3.917500
# 50%     23.283300   19.989200   67.045000   74.000000   70.500000    6.910000
# 75%     46.525800  105.711475   78.820000   87.000000   97.000000   11.100000
# max     78.218600  179.316700  108.320000  100.000000  100.000000   35.680000
#
#                Date
# count  5.740000e+02
# mean   1.653241e+09
# std    9.506208e+01
# min    1.653241e+09
# 25%    1.653241e+09
# 50%    1.653241e+09
# 75%    1.653242e+09
# max    1.653242e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Check if there are any cities that have humidity > 100%
cities_df.loc[cities_df["Humidity"] > 100]["Humidity"].count()
# Out:
# 0

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
cities_df.plot.scatter('Lat','Max Temp', c= "steelblue", edgecolor = "black", s=40)
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.title('City Latitude vs Max Temp (05/22/2022)')
plt.grid()
plt.savefig("Latitude_vs_Temperature Plot.png")
plt.show()

# %% [markdown]
# The latitude shows the different seasons in the Northern and Southern Hemispheres. After latitude 20N, a decrease in temperature can be noticed indicating that in the Northern Hemisphere is winter, and it's summer time in the Southern.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
cities_df.plot.scatter('Lat','Humidity', c= "steelblue", edgecolor = "black", s=40)
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title('City Latitude vs. Humidity (05/22/2022)')
plt.grid()
plt.savefig("Latitude_vs_Humidity Plot.png")
plt.show()

# %% [markdown]
# It can be noted that the humidity of the cities in the Southern Hemisphere between Latitude 60S and 0 cloudiness is less clusted, unlike in the Northern one.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cities_df.plot.scatter('Lat','Cloudiness', c= "steelblue", edgecolor = "black", s=40)
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.title('City Latitude vs. Cloudiness (05/22/2022)')
plt.grid()
plt.savefig("Latitude_vs_Cloudiness Plot.png")
plt.show()

# %% [markdown]
# The different cities' cloudiness throughout the Latitude span is clusted around the 0% and 100% marks.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
cities_df.plot.scatter('Lat','Wind Speed', c= "steelblue", edgecolor = "black", s=40)
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title('City Latitude vs. Wind Speed (05/22/2022)')
plt.grid()
plt.savefig("Latitude_vs_Wind Speed Plot.png")
plt.show()

# %% [markdown]
# Most of the cities wind speed goes up to 20 mph, with the highest speed registerd in the Northern Hemisphere.

# %% [markdown]
# ## Linear Regression

# %%
# Creating northern and southern hemisphere dataframe for linear regression:

northern_hem = cities_df.loc[cities_df["Lat"] >= 0]
southern_hem = cities_df.loc[cities_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(northern_hem['Lat'], northern_hem['Max Temp'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hem['Lat'], northern_hem['Max Temp'])
regress_values = northern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_hem['Lat'], northern_hem['Max Temp'])
plt.plot(northern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(25,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Max Temp vs. Latitude | Northern Hemisphere")
plt.savefig("Northern Hemisphere | Max Temp vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: -0.8060059338327754

# %% [markdown]
# In the Northern Hemisphere, as we move closer to the Arctic Circle the temperature decreases, hence the negative slope.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(southern_hem['Lat'], southern_hem['Max Temp'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hem['Lat'], southern_hem['Max Temp'])
regress_values = southern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_hem['Lat'], southern_hem['Max Temp'])
plt.plot(southern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Max Temp vs. Latitude | Southern Hemisphere")
plt.savefig("Southern Hemisphere | Max Temp vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: 0.8127070808315436

# %% [markdown]
# In the Southern Hemisphere, as we move closer to the Equator the temperature increases, hence the positive slope.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(northern_hem['Lat'], northern_hem['Humidity'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hem['Lat'], northern_hem['Humidity'])
regress_values = northern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_hem['Lat'], northern_hem['Humidity'])
plt.plot(northern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Humidity (%) vs. Latitude | Northern Hemisphere")
plt.savefig("Northern Hemisphere | Humidity (%) vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: 0.1830896027221642

# %% [markdown]
# In the Northern Hemisphere, as we move from the Equator to the Arctic Circle the humidity stays pretty consistent, hence the slope line is close to being parallel to the X-Axis.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(southern_hem['Lat'], southern_hem['Humidity'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hem['Lat'], southern_hem['Humidity'])
regress_values = southern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_hem['Lat'], southern_hem['Humidity'])
plt.plot(southern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-23,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Humidity (%) vs. Latitude | Southern Hemisphere")
plt.savefig("Southern Hemisphere | Humidity (%) vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: -0.04105759274605317

# %% [markdown]
# In the Southern Hemisphere, as we move towards the Equator to the Antarctic Circle the humidity stays pretty consistent, hence the slope line is close to being parallel to the X-Axis.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(northern_hem['Lat'], northern_hem['Cloudiness'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hem['Lat'], northern_hem['Cloudiness'])
regress_values = northern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_hem['Lat'], northern_hem['Cloudiness'])
plt.plot(northern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(45,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Cloudiness (%) vs. Latitude | Northern Hemisphere")
plt.savefig("Northern Hemisphere | Cloudiness (%) vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: 0.13636354438326795

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(southern_hem['Lat'], southern_hem['Cloudiness'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hem['Lat'], southern_hem['Cloudiness'])
regress_values = southern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_hem['Lat'], southern_hem['Cloudiness'])
plt.plot(southern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,65),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Cloudiness (%) vs. Latitude | Southern Hemisphere")
plt.savefig("Southern Hemisphere | Cloudiness (%) vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: -0.06728108039676482

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(northern_hem['Lat'], northern_hem['Wind Speed'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hem['Lat'], northern_hem['Wind Speed'])
regress_values = northern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(northern_hem['Lat'], northern_hem['Wind Speed'])
plt.plot(northern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(25,24),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Wind Speed (mph) vs. Latitude | Northern Hemisphere")
plt.savefig("Northern Hemisphere | Wind Speed (mph) vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: -0.006791482636631856

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
correlation = st.pearsonr(southern_hem['Lat'], southern_hem['Wind Speed'])
print(f"The r-value is: {correlation[0]}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hem['Lat'], southern_hem['Wind Speed'])
regress_values = southern_hem['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(southern_hem['Lat'], southern_hem['Wind Speed'])
plt.plot(southern_hem['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-25,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Wind Speed (mph) vs. Latitude | Southern Hemisphere")
plt.savefig("Southern Hemisphere | Wind Speed (mph) vs. Latitude Plot.png")
plt.show()
# Out:
# The r-value is: -0.1443656716099724
